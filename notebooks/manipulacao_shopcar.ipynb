# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from fuzzymatcher import link_table, fuzzy_left_join

# %%
df_anuncios = pd.read_csv('../airflow/staging/anuncios_shopcar.csv')
df_anuncios.columns = ['id_anuncio_shopcar', 'modelo', 'cor', 'combustivel', 'preco', 'km', 'link_anuncio', 'km', 'vendedor', 'cidade', 'ano_fabricacao', 'ano_modelo', 'estado_anuncio', 'endereco_anuncio', 'bairro_anuncio', 'marca', 'data_extracao_dados']

df_marca_modelo = pd.read_csv('../output/scrapping_marcas_modelos_fipe.csv')
# df_marca_modelo
# df_anuncios = df_anuncios.drop_duplicates(subset= ['modelo', 'marca'])[['modelo', 'marca']]
df_fuzzy = fuzzy_left_join(df_anuncios, df_marca_modelo, 'modelo', 'nome_modelo')
df_fuzzy = df_fuzzy.drop(labels= ['__id_left', '__id_right'], axis=1)
df_fuzzy[df_fuzzy.best_match_score > 0].sort_values(by= 'best_match_score')
# Out:
#          best_match_score   id_anuncio_shopcar  \
# 0                0.452912  1119811
# 1                0.147757  1121719
# 8                0.286311  1124108
# 157              0.291382  1124137
# 165              0.081174  1125059
# ...                   ...                  ...
# 1697746         -0.254413              1125120
# 1697857          0.513392              1043984
# 1697858          0.289740              1127848
# 1697900          0.323117              1116916
# 1698034          0.178657              1097718
#
#                                                     modelo              cor  \
# 0        Astra Sedan GLS 2.0 16v                       ...  Branca
# 1        Fiesta Hatch 1.0 4p.                          ...  Prata
# 8        Celta Life 1.0 4p.                            ...  Preta
# 157      Fiesta Sedan 1.6                              ...  Prata
# 165      Civic EX 1.6 16v A/T                          ...  Prata
# ...                                                    ...              ...
# 1697746                        Bonanza Custom 4.0TD Deluxe            Preta
# 1697857                              Doblo Essence 1.8 16v            Cinza
# 1697858                              Etios Hatch X 1.3 16v            Cinza
# 1697900                            Etios Hatch XLS 1.5 16v           Branca
# 1698034                          Fox Trendline 1.0 12v 4p.           Branca
#
#           combustivel         preco          km  \
# 0        Gasolina                    12900.0
# 1        Flex                        15200.0
# 8        Flex          203978.0      15500.0
# 157      Gasolina      220000.0      15900.0
# 165      Gasolina      200189.0      16000.0
# ...               ...           ...         ...
# 1697746        Diesel           NaN     40000.0
# 1697857          Flex           NaN     40000.0
# 1697858          Flex       54800.0     40000.0
# 1697900          Flex      118600.0     40000.0
# 1698034          Flex       64000.0     40000.0
#
#                                                 km  \
# 0        Federal Car 2
# 1        Lucas Flavio Nery
# 8        Alyne da Silva Amazonas
# 157      Marcos Marcelino Silva
# 165      Marcio Antônio Guimarães
# ...                                            ...
# 1697746                      Alex Soloaga da Cunha
# 1697857                   José Renato Mendes Pinto
# 1697858                               Nelson Tsuji
# 1697900                              Ueno Veículos
# 1698034                                MS Veículos
#
#                                               link_anuncio          km  ...  \
# 0        https://www.shopcar.com.br/veiculos/gm-chevrol...  12900.0     ...
# 1        https://www.shopcar.com.br/veiculos/ford/fiest...  15200.0     ...
# 8        https://www.shopcar.com.br/veiculos/gm-chevrol...  15500.0     ...
# 157      https://www.shopcar.com.br/veiculos/ford/fiest...  15900.0     ...
# 165      https://www.shopcar.com.br/veiculos/honda/civi...  16000.0     ...
# ...                                                    ...         ...  ...
# 1697746  https://www.shopcar.com.br/veiculos/gm-chevrol...     40000.0  ...
# 1697857  https://www.shopcar.com.br/veiculos/fiat/doblo...     40000.0  ...
# 1697858  https://www.shopcar.com.br/veiculos/toyota/eti...     40000.0  ...
# 1697900  https://www.shopcar.com.br/veiculos/toyota/eti...     40000.0  ...
# 1698034  https://www.shopcar.com.br/veiculos/vw-volkswa...     40000.0  ...
#
#                                             estado_anuncio  \
# 0           Av. Bandeirantes, 3006
# 1        Campo Grande
# 8        Campo Grande
# 157      Campo Grande
# 165      Campo Grande
# ...                                                    ...
# 1697746                                      Campo Grande
# 1697857                                      Campo Grande
# 1697858                                          Dourados
# 1697900                        Av. Weimar G. Torres, 3500
# 1698034                 Av. Weimar Gonçalves Torres, 3466
#
#                    endereco_anuncio                       bairro_anuncio  \
# 0        Nova Bandeirantes           Campo Grande
# 1        MS
# 8        MS
# 157      MS
# 165      MS
# ...                             ...                                  ...
# 1697746                          MS                                  NaN
# 1697857                          MS                                  NaN
# 1697858                          MS                                  NaN
# 1697900                     Centro                             Dourados
# 1698034                     Centro                             Dourados
#
#                     marca data_extracao_dados Unnamed: 0       nome_marca  \
# 0        gm-chevrolet              25/10/2021     2059.0   GM - Chevrolet
# 1        ford                      25/10/2021     1718.0             Ford
# 8        gm-chevrolet              25/10/2021     2103.0   GM - Chevrolet
# 157      ford                      25/10/2021     1741.0             Ford
# 165      honda                     25/10/2021     2572.0            Honda
# ...                   ...                 ...        ...              ...
# 1697746      gm-chevrolet          27/10/2021     2067.0   GM - Chevrolet
# 1697857              fiat          27/10/2021     1087.0             Fiat
# 1697858            toyota          27/10/2021     5302.0           Toyota
# 1697900            toyota          27/10/2021     5310.0           Toyota
# 1698034     vw-volkswagen          27/10/2021     6103.0  VW - VolksWagen
#
#         id_marca                               nome_modelo id_modelo
# 0           23.0  Astra Sedan 2.0/CD/ GLS/ Adv. 2.0 16V 4p     960.0
# 1           22.0                       Fiesta Class 1.0 4p     774.0
# 8           23.0             Celta Life 1.0 MPFI VHC 8V 3p     997.0
# 157         22.0            Fiesta Sedan 1.6 16V Flex Aut.    6521.0
# 165         25.0            Civic Coupe EX/ EXS 1.6 16V 2p    1248.0
# ...          ...                                       ...       ...
# 1697746     23.0                      Bonanza S / Luxe 4.1     968.0
# 1697857     21.0             Doblo ESSENCE 1.8 Flex 16V 5p    5536.0
# 1697858     56.0              ETIOS X 1.3 Flex 16V 5p Aut.    7560.0
# 1697900     56.0            ETIOS XLS 1.5 Flex 16V 5p Mec.    6248.0
# 1698034     59.0        VOYAGE Trendline 1.0 T.Flex 12V 4p    7524.0
#
# [19982 rows x 25 columns]

# %%
df_fuzzy[df_fuzzy.best_match_score > 0].sort_values(by= 'best_match_score')
# Out:
#          best_match_score   id_anuncio_shopcar  \
# 1016912          0.000701              1108511
# 174803           0.000701  1125886
# 252053           0.000701  1108511
# 1531359          0.001506              1111531
# 640591           0.001506  1111531
# ...                   ...                  ...
# 657223           1.068826  1042452
# 657221           1.068826  1026314
# 714108           1.068826  1121626
# 557375           1.086017  1096789
# 1664799          1.086017              1096789
#
#                                                     modelo              cor  \
# 1016912                                Corsa Hatch 1.0 4p.           Branca
# 174803   Corsa Hatch 1.0 4p.                           ...  Cinza
# 252053   Corsa Hatch 1.0 4p.                           ...  Branca
# 1531359                C 200 Avantgarde Sport 1.8T 16v A/T            Preta
# 640591   C 200 Avantgarde Sport 1.8T 16v A/T           ...  Preta
# ...                                                    ...              ...
# 657223   Jimny Sierra 4You 1.5 16v ALLGrip             ...  Bege
# 657221   Jimny Sierra 4You 1.5 16v ALLGrip             ...  Prata
# 714108   Jimny Sierra 4You 1.5 16v ALLGrip             ...  Cinza
# 557375   Up! Move 1.0 12v I-Motion 4p. A/T             ...  Branca
# 1664799                  Up! Move 1.0 12v I-Motion 4p. A/T           Branca
#
#           combustivel         preco          km  \
# 1016912          Flex           NaN     15000.0
# 174803   Gasolina                    10900.0
# 252053   Flex                        15000.0
# 1531359      Gasolina      150000.0     65000.0
# 640591   Gasolina      150000.0      65000.0
# ...               ...           ...         ...
# 657223   Gasolina
# 657221   Gasolina
# 714108   Gasolina      10000.0       124990.0
# 557375   Flex          21500.0       52900.0
# 1664799          Flex       21500.0     52900.0
#
#                                                 km  \
# 1016912                         Nova Car Seminovos
# 174803   Hélio Car Veículos
# 252053   Nova Car Seminovos
# 1531359                           Legacy Veículos
# 640591   Legacy Veículos
# ...                                            ...
# 657223   Vemais Suzuki
# 657221   Vemais Suzuki
# 714108   Odi Car Veículos
# 557375   Monte Carlo Veículos
# 1664799                       Monte Carlo Veículos
#
#                                               link_anuncio          km  ...  \
# 1016912  https://www.shopcar.com.br/veiculos/gm-chevrol...     15000.0  ...
# 174803   https://www.shopcar.com.br/veiculos/gm-chevrol...  10900.0     ...
# 252053   https://www.shopcar.com.br/veiculos/gm-chevrol...  15000.0     ...
# 1531359  https://www.shopcar.com.br/veiculos/mercedes-b...     65000.0  ...
# 640591   https://www.shopcar.com.br/veiculos/mercedes-b...  65000.0     ...
# ...                                                    ...         ...  ...
# 657223   https://www.shopcar.com.br/veiculos/suzuki/jim...              ...
# 657221   https://www.shopcar.com.br/veiculos/suzuki/jim...              ...
# 714108   https://www.shopcar.com.br/veiculos/suzuki/jim...  124990.0    ...
# 557375   https://www.shopcar.com.br/veiculos/vw-volkswa...  52900.0     ...
# 1664799  https://www.shopcar.com.br/veiculos/vw-volkswa...     52900.0  ...
#
#                                           estado_anuncio  \
# 1016912                        Rua Hayel Bon Faker, 710
# 174803   Av. Bandeirantes, 1743
# 252053   Rua Hayel Bon Faker, 710
# 1531359                       Av. Marechal Deodoro, 523
# 640591   Av. Marechal Deodoro, 523
# ...                                                  ...
# 657223   Av. Ricardo Brandão, 566
# 657221   Av. Ricardo Brandão, 566
# 714108   Av. Coronel Antonino, 352
# 557375   Rua Ediberto Celestino de Oliveira, 1870
# 1664799        Rua Ediberto Celestino de Oliveira, 1870
#
#                    endereco_anuncio                       bairro_anuncio  \
# 1016912            Jardim Água Boa                             Dourados
# 174803   Taquarussú                  Campo Grande
# 252053   Jardim Água Boa             Dourados
# 1531359                   Guanandi                         Campo Grande
# 640591   Guanandi                    Campo Grande
# ...                             ...                                  ...
# 657223   Itanhangá Park              Campo Grande
# 657221   Itanhangá Park              Campo Grande
# 714108   Coronel Antonino            Campo Grande
# 557375   Centro                      Dourados
# 1664799                     Centro                             Dourados
#
#                     marca data_extracao_dados Unnamed: 0       nome_marca  \
# 1016912      gm-chevrolet          26/10/2021     2182.0   GM - Chevrolet
# 174803   gm-chevrolet              25/10/2021     2182.0   GM - Chevrolet
# 252053   gm-chevrolet              25/10/2021     2182.0   GM - Chevrolet
# 1531359     mercedes-benz          26/10/2021     3509.0    Mercedes-Benz
# 640591   mercedes-benz             25/10/2021     3509.0    Mercedes-Benz
# ...                   ...                 ...        ...              ...
# 657223   suzuki                    25/10/2021     5197.0           Suzuki
# 657221   suzuki                    25/10/2021     5197.0           Suzuki
# 714108   suzuki                    25/10/2021     5197.0           Suzuki
# 557375   vw-volkswagen             25/10/2021     6062.0  VW - VolksWagen
# 1664799     vw-volkswagen          27/10/2021     6062.0  VW - VolksWagen
#
#         id_marca                               nome_modelo id_modelo
# 1016912     23.0            Corsa Super 1.0 MPFI / 2p e 4p    1054.0
# 174803      23.0            Corsa Super 1.0 MPFI / 2p e 4p    1054.0
# 252053      23.0            Corsa Super 1.0 MPFI / 2p e 4p    1054.0
# 1531359     39.0  C-200 CGI Touring Avantgarde 1.8 16V Aut    5348.0
# 640591      39.0  C-200 CGI Touring Avantgarde 1.8 16V Aut    5348.0
# ...          ...                                       ...       ...
# 657223      55.0    Jimny Sierra 4YOU ALLGRIP 1.5 16V Aut.    8873.0
# 657221      55.0    Jimny Sierra 4YOU ALLGRIP 1.5 16V Aut.    8873.0
# 714108      55.0    Jimny Sierra 4YOU ALLGRIP 1.5 16V Aut.    8873.0
# 557375      59.0      up! move I MOTION 1.0 T. Flex 12V 3p    6806.0
# 1664799     59.0      up! move I MOTION 1.0 T. Flex 12V 3p    6806.0
#
# [17515 rows x 25 columns]
