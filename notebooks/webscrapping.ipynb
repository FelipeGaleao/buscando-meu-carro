# %%
from bs4 import BeautifulSoup
import requests
import csv
import pandas

# %%
carro_dados = []
for pagina in range(5, 10):
    print(f"Iniciando scrapping ...... {pagina}")
    url = f"https://www.shopcar.com.br/busca.php?tipo=1&marca=&string=&ordenar=valor_asc&pagina={pagina}"
    res = requests.get(url)
    soup = BeautifulSoup(res.text)
    index = 0
    for carro in soup.find_all(class_='itens'):
        try:
            carro_modelo = carro('li')[1]('div')[0].get_text()
            anoModelo_anoFabricacao = carro('li')[1]('div')[2].get_text()
            corCarro = carro('li')[1]('div')[3].get_text()
            combustivelCarro = carro('li')[1]('div')[4].get_text()
            preco = carro(class_='preco')[0].get_text()
            try:
                kmCarro = carro(class_='caract-km')[0].get_text()
            except:
                kmCarro = 'Não disponível'
            link_veiculo = carro('a')[1].get('href')
            url = link_veiculo
            res = requests.get(url)
            soup = BeautifulSoup(res.text)
            vendedor = soup.find_all(class_='dados1')[0].find_all(class_='nome')[0].get_text()
            cidade = soup.find_all(class_='dados1')[0].find_all(class_='endereco')[0].get_text()
            index += 1
            carro_dados.append([carro_modelo, anoModelo_anoFabricacao, corCarro, combustivelCarro, kmCarro, preco, link_veiculo, vendedor, cidade])
            print(f"Já foram incluídos {index} carros")
        except: 
            pass
    # for carro in soup.find_all(class_='itens'):
    #     carro_modelo = carro('li')[1]('div')[0].get_text()
    #     anoModelo_anoFabricacao = carro('li')[1]('div')[2].get_text()
    #     corCarro = carro('li')[1]('div')[3].get_text()
    #     combustivelCarro = carro('li')[1]('div')[4].get_text()
    #     preco = carro(class_='preco')[0].get_text()
    #     try:
    #         kmCarro = carro(class_='caract-km')[0].get_text()
    #     except:
    #         kmCarro = 'Não disponível'
    #     link_veiculo = carro('a')[1].get('href')
    #     url = link_veiculo
    #     res = requests.get(url)
    #     soup = BeautifulSoup(res.text)
    #     vendedor = soup.find_all(class_='dados1')[0].find_all(class_='nome')[0].get_text()
    #     cidade = soup.find_all(class_='dados1')[0].find_all(class_='endereco')[0].get_text()
    #     index += 1
    #     carro_dados.append([carro_modelo, anoModelo_anoFabricacao, corCarro, combustivelCarro, kmCarro, preco, link_veiculo, vendedor, cidade])
        
    #     print(f"Já foram incluídos {index} carros")
# Out:
# Iniciando scrapping ...... 5
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Iniciando scrapping ...... 6
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Iniciando scrapping ...... 7
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Iniciando scrapping ...... 8
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Iniciando scrapping ...... 9
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros

# %%
# carros_df = pandas.DataFrame(carro_dados)
# carros_df.columns = ['Modelo', 'Ano', 'Cor',' Combustível','KM', 'Preco', 'Link', 'Vendedor', 'Cidade']
# carros_df.to_csv('output/scrapping_nuncios_shopcar.csv')

# %%
carro_dados
# Out:
# [['Logan Expression 1.0 16v',
#   '14/15',
#   'Prata',
#   'Flex',
#   'Não disponível',
#   'R$ 35.500,00',
#   'https://www.shopcar.com.br/veiculos/renault/logan-expression-1-0-16v/14-15/1143358',
#   'Amaral Motors',
#   'Av. Pres. Ernesto Geisel, 5701 - Cabreúva - Campo Grande / MS'],
#  ['Voyage Comfortline 1.6',
#   '11/12',
#   'Prata',
#   'Flex',
#   'Não disponível',
#   'R$ 35.900,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/voyage-comfortline-1-6/11-12/1121525',
#   'BS Automóveis',
#   'Rua Paraisópolis, 345 - Vila Santo Eugênio - Campo Grande / MS'],
#  ['Gol Trendline 1.0 4p.',
#   '14/15',
#   'Prata',
#   'Flex',
#   '76.850 Km',
#   'R$ 36.000,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/gol-trendline-1-0-4p/14-15/1120561',
#   'M Motors',
#   'Rua Jornalista Belizário Lima, 509 - Vila Gloria - Campo Grande / MS'],
#  ['Onix LT 1.0',
#   '12/13',
#   'Branca',
#   'Flex',
#   '97.800 Km',
#   'R$ 36.000,00',
#   'https://www.shopcar.com.br/veiculos/gm-chevrolet/onix-lt-1-0/12-13/1145219',
#   'Marcelo Maziero Medeiros',
#   'Campo Grande - MS'],
#  ['Punto Essence 1.6 16v',
#   '13/13',
#   'Branca',
#   'Flex',
#   'Não disponível',
#   'R$ 36.000,00',
#   'https://www.shopcar.com.br/veiculos/fiat/punto-essence-1-6-16v/13-13/1132798',
#   'Lolo Veículos',
#   'Rodovia MS 156, 2595 - Chácara Sidelis - Dourados / MS'],
#  ['Tucson GLS 2.0 16v A/T',
#   '09/10',
#   'Preta',
#   'Gasolina',
#   '174.000 Km',
#   'R$ 36.000,00',
#   'https://www.shopcar.com.br/veiculos/hyundai/tucson-gls-2-0-16v/09-10/1130249',
#   'M Motors',
#   'Rua Jornalista Belizário Lima, 509 - Vila Gloria - Campo Grande / MS'],
#  ['Saveiro Trend 1.6 C.E.',
#   '09/10',
#   'Prata',
#   'Flex',
#   'Não disponível',
#   'R$ 36.500,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/saveiro-trend-1-6-c-e/09-10/1133168',
#   'Seicar Veículos',
#   'Av. Bandeirantes, 2878 - Nova Bandeirantes - Campo Grande / MS'],
#  ['Gol Special 1.0 4p.',
#   '15/16',
#   'Branca',
#   'Flex',
#   'Não disponível',
#   'R$ 36.800,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/gol-special-1-0-4p/15-16/1144027',
#   'Marreco Veículos',
#   'Rua Amazonas, 1237 - Centro - Campo Grande / MS'],
#  ['Etios Hatch XS 1.3 16v',
#   '13/13',
#   'Cinza',
#   'Flex',
#   '119.644 Km',
#   'R$ 36.900,00',
#   'https://www.shopcar.com.br/veiculos/toyota/etios-hatch-xs-1-3-16v/13-13/1142943',
#   'Premium Auto Car',
#   'Av. Ricardo Brandão, 778 - Itanhangá Park - Campo Grande / MS'],
#  ['Gol 1.0 4p.',
#   '15/15',
#   'Preta',
#   'Flex',
#   '86.000 Km',
#   'R$ 36.900,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/gol-1-0-4p/15-15/1124992',
#   'Duarte Automóveis',
#   'Rua Dr. Paulo Machado, 383 - Jardim dos Estados - Campo Grande / MS'],
#  ['Golf Sportline 1.6',
#   '08/09',
#   'Prata',
#   'Flex',
#   '200.000 Km',
#   'R$ 36.900,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/golf-sportline-1-6/08-09/1139983',
#   'Bruno Barcelos de Oliveira',
#   'Campo Grande - MS'],
#  ['Palio Attractive 1.0 4p.',
#   '15/15',
#   'Branca',
#   'Flex',
#   '62.000 Km',
#   'R$ 36.900,00',
#   'https://www.shopcar.com.br/veiculos/fiat/palio-attractive-1-0-4p/15-15/1138984',
#   'Rota Autos e Negócios',
#   'Rua Calarge, 80 - Vila Carvalho - Campo Grande / MS'],
#  ['Fox 1.6 4p.',
#   '12/13',
#   'Branca',
#   'Flex',
#   '124.000 Km',
#   'R$ 37.500,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/fox-1-6-4p/12-13/1142577',
#   'K20 Motors',
#   'Rua Piriá, 1208 - Guanandi - Campo Grande / MS'],
#  ['Onix LT 1.0',
#   '13/13',
#   'Laranja',
#   'Flex',
#   'Não disponível',
#   'R$ 37.500,00',
#   'https://www.shopcar.com.br/veiculos/gm-chevrolet/onix-lt-1-0/13-13/1125112',
#   'MG Automóveis',
#   'Rua. Coronel Ponciano De Mattos Pereira, 2720 - Vila industrial - Dourados / MS'],
#  ['Palio Essence 1.6 16v Dualogic 4p. A/T',
#   '14/15',
#   'Branca',
#   'Flex',
#   '59.200 Km',
#   'R$ 37.500,00',
#   'https://www.shopcar.com.br/veiculos/fiat/palio-essence-1-6-16v-dualogic-4p/14-15/1127612',
#   'Marcos Frederico',
#   'Campo Grande - MS'],
#  ['Gol 1.6 4p.',
#   '14/14',
#   'Prata',
#   'Flex',
#   '131.000 Km',
#   'R$ 37.900,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/gol-1-6-4p/14-14/1067108',
#   'Império Veículos',
#   'Av. Bandeirantes, 2689 - Vila Bandeirante - Campo Grande / MS'],
#  ['Gol City 1.0 4p.',
#   '14/14',
#   'Branca',
#   'Flex',
#   'Não disponível',
#   'R$ 37.900,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/gol-city-1-0-4p/14-14/1138964',
#   'Federal Car',
#   'Av. Bandeirantes, 2236 - Nova Bandeirantes - Campo Grande / MS'],
#  ['Uno Mille Celebration Way 1.0 Fire 4p.',
#   '12/13',
#   'Prata',
#   'Flex',
#   '81.000 Km',
#   'R$ 37.990,00',
#   'https://www.shopcar.com.br/veiculos/fiat/uno-mille-celebration-way-1-0-fire-4p/12-13/1139607',
#   'Salles Automóveis',
#   'Rua Joaquim T. Alves, 2230 - Centro - Dourados / MS'],
#  ['Fiesta Hatch SE 1.6 16v Powershift A/T',
#   '13/14',
#   'Vermelha',
#   'Flex',
#   '87.500 Km',
#   'R$ 38.500,00',
#   'https://www.shopcar.com.br/veiculos/ford/fiesta-hatch-se-1-6-16v-powershift/13-14/1137839',
#   'Felipe Delai',
#   'Jardim - MS'],
#  ['Ka SE 1.0 12v',
#   '14/15',
#   'Prata',
#   'Flex',
#   '84.000 Km',
#   'R$ 38.900,00',
#   'https://www.shopcar.com.br/veiculos/ford/ka-se-1-0-12v/14-15/1140514',
#   'Vandercleiton Escobar',
#   'Campo Grande - MS'],
#  ['Logan Expression 1.6',
#   '14/14',
#   'Prata',
#   'Flex',
#   '91.300 Km',
#   'R$ 38.900,00',
#   'https://www.shopcar.com.br/veiculos/renault/logan-expression-1-6/14-14/1118660',
#   'Império Veículos',
#   'Av. Bandeirantes, 2689 - Vila Bandeirante - Campo Grande / MS'],
#  ['Voyage 1.6',
#   '13/13',
#   'Prata',
#   'Flex',
#   '68.000 Km',
#   'R$ 38.900,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/voyage-1-6/13-13/1143930',
#   'Marcelo ',
#   'Campo Grande - MS'],
#  ['Cobalt LTZ 1.8',
#   '12/13',
#   'Branca',
#   'Flex',
#   '120.000 Km',
#   'R$ 38.990,00',
#   'https://www.shopcar.com.br/veiculos/gm-chevrolet/cobalt-ltz-1-8/12-13/1123796',
#   'BM Motors',
#   'Avenida Presidente Ernesto Geisel, 6103 - Cabreuva - Campo Grande / MS'],
#  ['Mobi Drive 1.0',
#   '17/18',
#   'Preta',
#   'Flex',
#   '157.000 Km',
#   'R$ 39.000,00',
#   'https://www.shopcar.com.br/veiculos/fiat/mobi-drive-1-0/17-18/1140762',
#   'Mauro Luiz Martines',
#   'Campo Grande - MS'],
#  ['Montana Sport 1.4',
#   '11/12',
#   'Preta',
#   'Flex',
#   '130.000 Km',
#   'R$ 39.000,00',
#   'https://www.shopcar.com.br/veiculos/gm-chevrolet/montana-sport-1-4/11-12/1143986',
#   'Robson Viana',
#   'Ponta Porã - MS'],
#  ['Fiesta Hatch S 1.5 16v',
#   '13/13',
#   'Prata',
#   'Flex',
#   '77.000 Km',
#   'R$ 39.500,00',
#   'https://www.shopcar.com.br/veiculos/ford/fiesta-hatch-s-1-5-16v/13-13/1145044',
#   'Geovania de Santana Martins',
#   'Campo Grande - MS'],
#  ['Gol Highline 1.6 4p.',
#   '13/14',
#   'Prata',
#   'Flex',
#   'Não disponível',
#   'R$ 39.800,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/gol-highline-1-6-4p/13-14/1130204',
#   'Neura Pereira Meireles',
#   'Campo Grande - MS'],
#  ['Santa Fe GLS 2.7 V6 24v A/T',
#   '07/08',
#   'Prata',
#   'Gasolina',
#   'Não disponível',
#   'R$ 39.800,00',
#   'https://www.shopcar.com.br/veiculos/hyundai/santa-fe-gls-2-7-v6-24v/07-08/1127767',
#   'M.G.R. Veículos',
#   'Av. Afonso Pena, 3865 - Centro - Campo Grande / MS'],
#  ['Fiesta Hatch S 1.5 16v',
#   '14/14',
#   'Prata',
#   'Flex',
#   '54.700 Km',
#   'R$ 39.900,00',
#   'https://www.shopcar.com.br/veiculos/ford/fiesta-hatch-s-1-5-16v/14-14/1138743',
#   'Igor Miyashiro',
#   'Campo Grande - MS'],
#  ['Gol 1.6 I-Motion 4p. A/T',
#   '13/14',
#   'Preta',
#   'Flex',
#   '75.000 Km',
#   'R$ 39.900,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/gol-1-6-i-motion-4p/13-14/1128680',
#   'Irajá Keniti Brun',
#   'Campo Grande - MS'],
#  ['Onix LT 1.0',
#   '16/16',
#   'Grafite',
#   'Flex',
#   '80.000 Km',
#   'R$ 39.900,00',
#   'https://www.shopcar.com.br/veiculos/gm-chevrolet/onix-lt-1-0/16-16/1139933',
#   'Yago Azevedo da Costa',
#   'Campo Grande - MS'],
#  ['Sandero StepWay 1.6 16v',
#   '14/14',
#   'Preta',
#   'Flex',
#   'Não disponível',
#   'R$ 39.990,00',
#   'https://www.shopcar.com.br/veiculos/renault/sandero-stepway-1-6-16v/14-14/1139707',
#   'New Car Multimarcas',
#   'Rua do Rosário, 259 - Vila Gomes - Campo Grande / MS'],
#  ['Saveiro 1.6 C.E.',
#   '11/12',
#   'Branca',
#   'Flex',
#   '146.440 Km',
#   'R$ 39.990,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/saveiro-1-6-c-e/11-12/1121368',
#   'Pelegrinelli Veículos',
#   'Av. Rachid Neder, 696 - Monte Castelo - Campo Grande / MS'],
#  ['C4 Picasso 2.0 16v A/T',
#   '13/14',
#   'Preta',
#   'Gasolina',
#   '122.500 Km',
#   'R$ 40.000,00',
#   'https://www.shopcar.com.br/veiculos/citro-n/c4-picasso-2-0-16v/13-14/1144312',
#   'Egon Leon Dadalt',
#   'Campo Grande - MS'],
#  ['Up! High 1.0 12v 4p.',
#   '14/15',
#   'Amarela',
#   'Flex',
#   '132.000 Km',
#   'R$ 40.900,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/up-high-1-0-12v-4p/14-15/1122007',
#   'Interlagos Automóveis',
#   'R. Maranhão,  335 - Vila Rica - Campo Grande / MS'],
#  ['HB20 Comfort 1.0 12v',
#   '14/15',
#   'Preta',
#   'Flex',
#   'Não disponível',
#   'R$ 40.990,00',
#   'https://www.shopcar.com.br/veiculos/hyundai/hb20-comfort-1-0-12v/14-15/1138502',
#   'New Car Multimarcas',
#   'Rua do Rosário, 259 - Vila Gomes - Campo Grande / MS'],
#  ['Fit LX 1.4 16v A/T',
#   '10/10',
#   'Preta',
#   'Flex',
#   '154.000 Km',
#   'R$ 41.500,00',
#   'https://www.shopcar.com.br/veiculos/honda/fit-lx-1-4-16v/10-10/1140730',
#   'Cláudio Cesar Batista de Oliveira',
#   'Campo Grande - MS'],
#  ['Montana LS 1.4',
#   '14/15',
#   'Branca',
#   'Flex',
#   '40.261 Km',
#   'R$ 41.500,00',
#   'https://www.shopcar.com.br/veiculos/gm-chevrolet/montana-ls-1-4/14-15/1143384',
#   'Euripedes de Oliveira Sousa',
#   'Campo Grande - MS'],
#  ['Sandero Authentique 1.0 12v',
#   '18/19',
#   'Branca',
#   'Flex',
#   'Não disponível',
#   'R$ 41.800,00',
#   'https://www.shopcar.com.br/veiculos/renault/sandero-authentique-1-0-12v/18-19/1086198',
#   'Art Motors',
#   'Av. Bandeirantes, 242 - Amambaí - Campo Grande / MS'],
#  ['Cerato SX 1.6 16v A/T',
#   '10/11',
#   'Preta',
#   'Flex',
#   '102.000 Km',
#   'R$ 41.900,00',
#   'https://www.shopcar.com.br/veiculos/kia/cerato-sx-1-6-16v/10-11/1115567',
#   'Procurocar Carros e Negócios',
#   'Av. Salgado Filho, 987 - Amambaí - Campo Grande / MS'],
#  ['Fluence Dynamique 2.0 16v A/T',
#   '12/13',
#   'Preta',
#   'Flex',
#   '102.000 Km',
#   'R$ 41.900,00',
#   'https://www.shopcar.com.br/veiculos/renault/fluence-dynamique-2-0-16v/12-13/999056',
#   'Achiles Pena Mendes',
#   'Campo Grande - MS'],
#  ['Logan Authentique 1.0 16v',
#   '16/17',
#   'Cinza',
#   'Flex',
#   'Não disponível',
#   'R$ 41.900,00',
#   'https://www.shopcar.com.br/veiculos/renault/logan-authentique-1-0-16v/16-17/1140682',
#   'Águia Veículos',
#   'Av. Bandeirantes, 1333 - Taquarussu - Campo Grande / MS'],
#  ['Mobi Like 1.0',
#   '17/18',
#   'Preta',
#   'Flex',
#   '77.865 Km',
#   'R$ 41.900,00',
#   'https://www.shopcar.com.br/veiculos/fiat/mobi-like-1-0/17-18/1134317',
#   'Premium Motors',
#   'Rua João Pedro de Souza,73 - Jardim Monte Líbano - Campo Grande / MS'],
#  ['Palio Sporting 1.6 16v 4p.',
#   '14/15',
#   'Branca',
#   'Flex',
#   '63.500 Km',
#   'R$ 41.900,00',
#   'https://www.shopcar.com.br/veiculos/fiat/palio-sporting-1-6-16v-4p/14-15/1144659',
#   'Igor Gabriel Pagliarini',
#   'Deodápolis - MS'],
#  ['Gol Comfortline 1.6 4p.',
#   '14/15',
#   'Branca',
#   'Flex',
#   '117.000 Km',
#   'R$ 41.990,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/gol-comfortline-1-6-4p/14-15/1140303',
#   'CR Motors',
#   'Rua Joaquim Murtinho, 1872 - Itanhangá Park - Campo Grande / MS'],
#  ['Pajero TR4 2.0 16v 4x4',
#   '08/09',
#   'Prata',
#   'Flex',
#   '132.259 Km',
#   'R$ 41.990,00',
#   'https://www.shopcar.com.br/veiculos/mitsubishi/pajero-tr4-2-0-16v-4x4/08-09/1141663',
#   'Pelegrinelli Veículos',
#   'Av. Rachid Neder, 696 - Monte Castelo - Campo Grande / MS'],
#  ['Etios Hatch XLS 1.5 16v',
#   '14/14',
#   'Preta',
#   'Flex',
#   '85.328 Km',
#   'R$ 42.000,00',
#   'https://www.shopcar.com.br/veiculos/toyota/etios-hatch-xls-1-5-16v/14-14/1136059',
#   'FM Veículos',
#   'Rua Munir Thomé, 566 - Centro - Três Lagoas / MS'],
#  ['Fit EXL 1.5 16v A/T',
#   '10/11',
#   'Cinza',
#   'Flex',
#   '81.000 Km',
#   'R$ 42.000,00',
#   'https://www.shopcar.com.br/veiculos/honda/fit-exl-1-5-16v/10-11/1140311',
#   'Rafael Antunes Abud',
#   'Campo Grande - MS'],
#  ['Hilux DLX 2.8D C.D.',
#   '98/98',
#   'Branca',
#   'Diesel',
#   '287.000 Km',
#   'R$ 42.000,00',
#   'https://www.shopcar.com.br/veiculos/toyota/hilux-dlx-2-8d-c-d/98-98/1115697',
#   'Nill Car',
#   'Rua 26 de Agosto, 1580 - Amambaí - Campo Grande / MS'],
#  ['Mobi Like 1.0',
#   '18/18',
#   'Branca',
#   'Flex',
#   '89.300 Km',
#   'R$ 42.000,00',
#   'https://www.shopcar.com.br/veiculos/fiat/mobi-like-1-0/18-18/1133319',
#   'Tony Automóveis',
#   'Rua Dr. Boaventura, 800 - Centro - Rio Brilhante / MS'],
#  ['Saveiro Trend 1.6 C.E.',
#   '13/14',
#   'Prata',
#   'Flex',
#   '126.000 Km',
#   'R$ 42.500,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/saveiro-trend-1-6-c-e/13-14/1119146',
#   'Lolo Veículos',
#   'Rodovia MS 156, 2595 - Chácara Sidelis - Dourados / MS'],
#  ['City LX 1.5 16v A/T',
#   '10/10',
#   'Prata',
#   'Gasolina',
#   'Não disponível',
#   'R$ 42.900,00',
#   'https://www.shopcar.com.br/veiculos/honda/city-lx-1-5-16v/10-10/1113884',
#   'Seicar Veículos',
#   'Av. Bandeirantes, 2878 - Nova Bandeirantes - Campo Grande / MS'],
#  ['Uno Attractive 1.0 4p.',
#   '19/20',
#   'Branca',
#   'Flex',
#   '98.000 Km',
#   'R$ 42.900,00',
#   'https://www.shopcar.com.br/veiculos/fiat/uno-attractive-1-0-4p/19-20/1139698',
#   'MS Multimarcas',
#   ' Av. Cel. Antonino, 1505 - Cel. Antonino - Campo Grande / MS'],
#  ['Gol Trendline 1.0 12v 4p.',
#   '16/17',
#   'Cinza',
#   'Flex',
#   'Não disponível',
#   'R$ 42.990,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/gol-trendline-1-0-12v-4p/16-17/1141492',
#   'New Car Multimarcas',
#   'Rua do Rosário, 259 - Vila Gomes - Campo Grande / MS'],
#  ['Grand Siena Essence 1.6 16v',
#   '14/15',
#   'Prata',
#   'Flex',
#   '133.000 Km',
#   'R$ 42.990,00',
#   'https://www.shopcar.com.br/veiculos/fiat/grand-siena-essence-1-6-16v/14-15/1142358',
#   'Sua Oferta Veículos',
#   'Rua Alegrete, 1203 - Coronel Antonino - Campo Grande / MS'],
#  ['Sandero Expression 1.0 12v',
#   '18/19',
#   'Preta',
#   'Flex',
#   '74.000 Km',
#   'R$ 42.990,00',
#   'https://www.shopcar.com.br/veiculos/renault/sandero-expression-1-0-12v/18-19/1141668',
#   'Sua Oferta Veículos',
#   'Rua Alegrete, 1203 - Coronel Antonino - Campo Grande / MS'],
#  ['HB20 Comfort Plus 1.6 16v',
#   '12/13',
#   'Cinza',
#   'Flex',
#   '111.347 Km',
#   'R$ 43.000,00',
#   'https://www.shopcar.com.br/veiculos/hyundai/hb20-comfort-plus-1-6-16v/12-13/1135577',
#   'FM Veículos',
#   'Rua Munir Thomé, 566 - Centro - Três Lagoas / MS'],
#  ['Voyage Trendline 1.6',
#   '15/16',
#   'Prata',
#   'Flex',
#   '79.500 Km',
#   'R$ 43.300,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/voyage-trendline-1-6/15-16/1119560',
#   'Elizete de Jesus Nantes da Cunha ',
#   'Campo Grande - MS'],
#  ['Gol Trendline 1.0 12v 4p.',
#   '16/17',
#   'Prata',
#   'Flex',
#   'Não disponível',
#   'R$ 43.900,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/gol-trendline-1-0-12v-4p/16-17/1125519',
#   'Auto 1000 Multimarcas',
#   'Av. Bandeirantes, 2253 - Taquarussu - Campo Grande / MS'],
#  ['Gol Trendline 1.0 12v 4p.',
#   '18/18',
#   'Branca',
#   'Flex',
#   '50.000 Km',
#   'R$ 43.990,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/gol-trendline-1-0-12v-4p/18-18/1137345',
#   'New Car Multimarcas',
#   'Rua do Rosário, 259 - Vila Gomes - Campo Grande / MS'],
#  ['HB20 Comfort Plus 1.0 12v',
#   '15/15',
#   'Preta',
#   'Flex',
#   '73.050 Km',
#   'R$ 43.990,00',
#   'https://www.shopcar.com.br/veiculos/hyundai/hb20-comfort-plus-1-0-12v/15-15/1140919',
#   'Automóbile Multimarcas',
#   'Av. Ricardo Brandão, 646 - Itanhangá Park - Campo Grande / MS'],
#  ['HB20 Premium 1.6 16v',
#   '12/13',
#   'Prata',
#   'Flex',
#   '97.888 Km',
#   'R$ 43.990,00',
#   'https://www.shopcar.com.br/veiculos/hyundai/hb20-premium-1-6-16v/12-13/1143863',
#   'Pelegrinelli Veículos',
#   'Av. Rachid Neder, 696 - Monte Castelo - Campo Grande / MS'],
#  ['Punto Attractive 1.4',
#   '14/15',
#   'Branca',
#   'Flex',
#   '71.639 Km',
#   'R$ 43.990,00',
#   'https://www.shopcar.com.br/veiculos/fiat/punto-attractive-1-4/14-15/1139854',
#   'Teca Automóveis',
#   'Rua 13 de Maio, 3843 - Centro - Campo Grande / MS'],
#  ['Saveiro Trend 1.6 C.S.',
#   '13/14',
#   'Prata',
#   'Flex',
#   '108.000 Km',
#   'R$ 44.000,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/saveiro-trend-1-6-c-s/13-14/1119727',
#   'Griff Car Veículos',
#   'Av. Weimar Gonçalves Torres, 3235 - Centro - Dourados / MS'],
#  ['Mobi Like 1.0',
#   '19/20',
#   'Branca',
#   'Flex',
#   '35.000 Km',
#   'R$ 44.500,00',
#   'https://www.shopcar.com.br/veiculos/fiat/mobi-like-1-0/19-20/1131129',
#   'Huracam Motors',
#   'Rua Eduardo Elias Zarhan, 1934 - Jardim TV Morena - Campo Grande / MS'],
#  ['Fit Twist 1.5 16v',
#   '12/13',
#   'Azul',
#   'Flex',
#   '118.130 Km',
#   'R$ 44.800,00',
#   'https://www.shopcar.com.br/veiculos/honda/fit-twist-1-5-16v/12-13/1144212',
#   'Isaac Laitart',
#   'Campo Grande - MS'],
#  ['Kwid Zen 1.0 12v',
#   '19/20',
#   'Branca',
#   'Flex',
#   '80.300 Km',
#   'R$ 44.800,00',
#   'https://www.shopcar.com.br/veiculos/renault/kwid-zen-1-0-12v/19-20/1140248',
#   'Eduardo',
#   'Campo Grande - MS'],
#  ['Fiesta Hatch SE 1.6 16v Powershift A/T',
#   '14/15',
#   'Preta',
#   'Flex',
#   '56.000 Km',
#   'R$ 44.900,00',
#   'https://www.shopcar.com.br/veiculos/ford/fiesta-hatch-se-1-6-16v-powershift/14-15/1143409',
#   'Erick',
#   'Campo Grande - MS'],
#  ['Ka SE 1.0 12v',
#   '15/15',
#   'Branca',
#   'Flex',
#   '62.000 Km',
#   'R$ 45.000,00',
#   'https://www.shopcar.com.br/veiculos/ford/ka-se-1-0-12v/15-15/1138222',
#   'Luana Jose Gomes',
#   'Campo Grande - MS'],
#  ['Fit EX 1.5 16v A/T',
#   '10/11',
#   'Chumbo',
#   'Flex',
#   '82.000 Km',
#   'R$ 45.900,00',
#   'https://www.shopcar.com.br/veiculos/honda/fit-ex-1-5-16v/10-11/1144807',
#   'Wilker de Jesus Jardim de Souza',
#   'Dourados - MS'],
#  ['Fox Comfortline 1.0 4p.',
#   '16/17',
#   'Branca',
#   'Flex',
#   'Não disponível',
#   'R$ 45.900,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/fox-comfortline-1-0-4p/16-17/1137001',
#   'Seicar Veículos',
#   'Av. Bandeirantes, 2878 - Nova Bandeirantes - Campo Grande / MS'],
#  ['HB20 Comfort 1.0 12v',
#   '16/17',
#   'Preta',
#   'Flex',
#   '97.000 Km',
#   'R$ 45.900,00',
#   'https://www.shopcar.com.br/veiculos/hyundai/hb20-comfort-1-0-12v/16-17/1134830',
#   'Vale Veículos',
#   'Av. Fernando Correa da Costa, 2099 - Jardim Aclimação - Campo Grande / MS'],
#  ['C4 Lounge Tendance 2.0 16v A/T',
#   '13/14',
#   'Preta',
#   'Flex',
#   '78.000 Km',
#   'R$ 45.990,00',
#   'https://www.shopcar.com.br/veiculos/citro-n/c4-lounge-tendance-2-0-16v/13-14/1107503',
#   'New Car Multimarcas',
#   'Rua do Rosário, 259 - Vila Gomes - Campo Grande / MS'],
#  ['Fiesta Hatch S 1.5 16v',
#   '15/16',
#   'Branca',
#   'Flex',
#   '25.100 Km',
#   'R$ 45.990,00',
#   'https://www.shopcar.com.br/veiculos/ford/fiesta-hatch-s-1-5-16v/15-16/1124365',
#   'Automóbile Multimarcas',
#   'Av. Ricardo Brandão, 646 - Itanhangá Park - Campo Grande / MS'],
#  ['Strada Adventure 1.8 C.D.',
#   '09/10',
#   'Verde',
#   'Flex',
#   '125.550 Km',
#   'R$ 45.990,00',
#   'https://www.shopcar.com.br/veiculos/fiat/strada-adventure-1-8-c-d/09-10/1130465',
#   'Automóbile Multimarcas',
#   'Av. Ricardo Brandão, 646 - Itanhangá Park - Campo Grande / MS'],
#  ['Versa S 1.0 12v',
#   '16/16',
#   'Preta',
#   'Flex',
#   '47.500 Km',
#   'R$ 45.990,00',
#   'https://www.shopcar.com.br/veiculos/nissan/versa-s-1-0-12v/16-16/1143421',
#   'Autobel Veículos',
#   'Av. Afonso Pena, 5533 - Santa Fé - Campo Grande / MS'],
#  ['Strada Hard Working 1.4 C.S.',
#   '14/15',
#   'Branca',
#   'Flex',
#   'Não disponível',
#   'R$ 46.000,00',
#   'https://www.shopcar.com.br/veiculos/fiat/strada-hard-working-1-4-c-s/14-15/1137578',
#   'M.G.R. Veículos',
#   'Av. Afonso Pena, 3865 - Centro - Campo Grande / MS'],
#  ['Kwid Zen 1.0 12v',
#   '19/20',
#   'Prata',
#   'Flex',
#   '39.000 Km',
#   'R$ 46.500,00',
#   'https://www.shopcar.com.br/veiculos/renault/kwid-zen-1-0-12v/19-20/1142808',
#   'Huracam Motors',
#   'Rua Eduardo Elias Zarhan, 1934 - Jardim TV Morena - Campo Grande / MS'],
#  ['Prisma Advantage 1.0',
#   '14/15',
#   'Branca',
#   'Flex',
#   'Não disponível',
#   'R$ 46.800,00',
#   'https://www.shopcar.com.br/veiculos/gm-chevrolet/prisma-advantage-1-0/14-15/1140164',
#   'Marreco Veículos',
#   'Rua Amazonas, 1237 - Centro - Campo Grande / MS'],
#  ['Palio Sporting 1.6 16v 4p.',
#   '15/16',
#   'Branca',
#   'Flex',
#   '71.020 Km',
#   'R$ 46.900,00',
#   'https://www.shopcar.com.br/veiculos/fiat/palio-sporting-1-6-16v-4p/15-16/1125514',
#   'Auto 1000 Multimarcas',
#   'Av. Bandeirantes, 2253 - Taquarussu - Campo Grande / MS'],
#  ['Spin LT 1.8',
#   '13/13',
#   'Branca',
#   'Flex',
#   '108.000 Km',
#   'R$ 46.900,00',
#   'https://www.shopcar.com.br/veiculos/gm-chevrolet/spin-lt-1-8/13-13/1139268',
#   'Mclaren Automóveis',
#   'Av. Bandeirantes, 1246 - Vila Bandeirante - Campo Grande / MS'],
#  ['Strada Working 1.4 C.S.',
#   '16/16',
#   'Branca',
#   'Flex',
#   'Não disponível',
#   'R$ 46.900,00',
#   'https://www.shopcar.com.br/veiculos/fiat/strada-working-1-4-c-s/16-16/1139089',
#   'Seicar Veículos',
#   'Av. Bandeirantes, 2878 - Nova Bandeirantes - Campo Grande / MS'],
#  ['Strada Working 1.4 C.S.',
#   '14/15',
#   'Branca',
#   'Flex',
#   '87.000 Km',
#   'R$ 46.900,00',
#   'https://www.shopcar.com.br/veiculos/fiat/strada-working-1-4-c-s/14-15/1139064',
#   'Vale Veículos',
#   'Av. Fernando Correa da Costa, 2099 - Jardim Aclimação - Campo Grande / MS'],
#  ['Uno Attractive 1.0 4p.',
#   '19/20',
#   'Branca',
#   'Flex',
#   '95.000 Km',
#   'R$ 46.900,00',
#   'https://www.shopcar.com.br/veiculos/fiat/uno-attractive-1-0-4p/19-20/1132160',
#   'Mclaren Automóveis',
#   'Av. Bandeirantes, 1246 - Vila Bandeirante - Campo Grande / MS'],
#  ['HB20 Comfort Style 1.0 12v',
#   '15/16',
#   'Branca',
#   'Flex',
#   '101.500 Km',
#   'R$ 46.990,00',
#   'https://www.shopcar.com.br/veiculos/hyundai/hb20-comfort-style-1-0-12v/15-16/1139819',
#   'Michel Cristian Molinas Franco',
#   'Campo Grande - MS']]
