# %%
from platform import platform
import pandas 
import json 
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromiumService
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.core.utils import ChromeType

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))


pagina = 3
print(f"Iniciando scrapping ...... {pagina}")


url = f"https://www.shopcar.com.br/busca.php?tipo=1&marca=&string=&ordenar=valor_asc&pagina={pagina}"
driver.get(url)
res = driver.page_source
soup = BeautifulSoup(res, "html.parser")
index = 0
carro_dados = []

for carro in soup.find_all(class_='itens'):
    carro_detalhes = carro.select(".coluna-2")
    try:
        carro_modelo = carro_detalhes[0]('div')[0].get_text()
        anoModelo_anoFabricacao = carro_detalhes[0]('div')[2].get_text()
        corCarro = carro_detalhes[0]('div')[3].get_text()
        combustivelCarro = carro_detalhes[0]('div')[4].get_text()
        preco = carro_detalhes[0]('div')[7].get_text()
        try:
            kmCarro = carro[0]('div')[5].get_text()
        except:
            kmCarro = 'Não disponível'
        link_veiculo = carro('a')[1].get('href')
        url = link_veiculo
        driver.get(url)
        res = driver.page_source
        soup = BeautifulSoup(res)
        vendedor = soup.find_all(class_='dados1')[0].find_all(class_='nome')[0].get_text()
        cidade = soup.find_all(class_='dados1')[0].find_all(class_='endereco')[0].get_text()
        carro_dados.append([carro_modelo, anoModelo_anoFabricacao, corCarro, combustivelCarro, kmCarro, preco, link_veiculo, vendedor, cidade])
    except:
        pass
# Out:
# Iniciando scrapping ...... 3

# %%
import pandas 
import json 
import requests
from bs4 import BeautifulSoup
import cloudscraper
from selenium import webdriver
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options

chrome_options = Options()
#chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
#chrome_options.add_argument('--disable-dev-shm-usage')  

print(f"Iniciando scrapping ...... {pagina}")
url = f"https://www.shopcar.com.br/busca.php?tipo=1&marca=&string=&ordenar=valor_asc&pagina={pagina}"
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()), chrome_options=chrome_options)

driver.get(url)

res = driver.page_source
soup = BeautifulSoup(res, "html.parser")
index = 0
carro_dados = []

for carro in soup.find_all(class_='itens'):
    carro_detalhes = carro.select(".coluna-2")
    try:
        carro_modelo = carro_detalhes[0]('div')[0].get_text()
        anoModelo_anoFabricacao = carro_detalhes[0]('div')[2].get_text()
        corCarro = carro_detalhes[0]('div')[3].get_text()
        combustivelCarro = carro_detalhes[0]('div')[4].get_text()
        preco = carro_detalhes[0]('div')[7].get_text()
        try:
            kmCarro = carro[0]('div')[5].get_text()
        except:
            kmCarro = 'Não disponível'
        link_veiculo = carro('a')[1].get('href')
        url = link_veiculo
        driver.get(url)
        res = driver.page_source
        soup = BeautifulSoup(res)
        vendedor = soup.find_all(class_='dados1')[0].find_all(class_='nome')[0].get_text()
        cidade = soup.find_all(class_='dados1')[0].find_all(class_='endereco')[0].get_text()
        carro_dados.append([carro_modelo, anoModelo_anoFabricacao, corCarro, combustivelCarro, kmCarro, preco, link_veiculo, vendedor, cidade])
    except:
        pass
    
carros_df = pandas.DataFrame(carro_dados)
print(carro_dados)
# Out:
# Iniciando scrapping ...... 3
# C:\Users\mayco\AppData\Local\Temp/ipykernel_1368/1962832514.py:19: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()), chrome_options=chrome_options)
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1368/1962832514.py in <module>
#      21 driver.get(url)
#      22
# ---> 23 res = driver.page_source
#      24 soup = BeautifulSoup(res, "html.parser")
#      25 index = 0
#
# d:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     539                 driver.page_source
#     540         """
# --> 541         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     542
#     543     def close(self) -> None:
#
# d:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     433         response = self.command_executor.execute(driver_command, params)
#     434         if response:
# --> 435             self.error_handler.check_response(response)
#     436             response['value'] = self._unwrap_value(
#     437                 response.get('value', None))
#
# d:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=103.0.5060.134)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x010D5FD3+2187219]
# 	Ordinal0 [0x0106E6D1+1763025]
# 	Ordinal0 [0x00F83E78+802424]
# 	Ordinal0 [0x00F6C680+706176]
# 	Ordinal0 [0x00FCF519+1111321]
# 	Ordinal0 [0x00FDC762+1165154]
# 	Ordinal0 [0x00FCC9A6+1100198]
# 	Ordinal0 [0x00FA6F80+946048]
# 	Ordinal0 [0x00FA7E76+949878]
# 	GetHandleVerifier [0x013790C2+2721218]
# 	GetHandleVerifier [0x0136AAF0+2662384]
# 	GetHandleVerifier [0x0116137A+526458]
# 	GetHandleVerifier [0x01160416+522518]
# 	Ordinal0 [0x01074EAB+1789611]
# 	Ordinal0 [0x010797A8+1808296]
# 	Ordinal0 [0x01079895+1808533]
# 	Ordinal0 [0x010826C1+1844929]
# 	BaseThreadInitThunk [0x7698FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77997A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77997A6E+238]

# %%
carro_dados
# Out:
# [['Voyage Trend 1.0',
#   '08/09',
#   'Preta',
#   'Flex',
#   'Não disponível',
#   'DETALHES',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/voyage-trend-1-0/08-09/1198854',
#   'Seicar Veículos',
#   'Av. Bandeirantes, 2878 - Nova Bandeirantes - Campo Grande / MS'],
#  ['Sandero Expression 1.0 16v',
#   '12/13',
#   'Branca',
#   'Flex',
#   'Não disponível',
#   'R$\xa028.990,00',
#   'https://www.shopcar.com.br/veiculos/renault/sandero-expression-1-0-16v/12-13/1196748',
#   'BM Motors',
#   'Avenida Presidente Ernesto Geisel, 6103 - Cabreuva - Campo Grande / MS'],
#  ['Fox Trend 1.0 4p.',
#   '10/11',
#   'Prata',
#   'Flex',
#   'Não disponível',
#   'DETALHES',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/fox-trend-1-0-4p/10-11/1196325',
#   'KV Veículos',
#   'R. Alegrete, 2139 - Cel. Antonino - Campo Grande / MS'],
#  ['Fiesta Hatch SE 1.0 4p.',
#   '13/14',
#   'Preta',
#   'Flex',
#   'Não disponível',
#   'R$\xa029.900,00',
#   'https://www.shopcar.com.br/veiculos/ford/fiesta-hatch-se-1-0-4p/13-14/1185268',
#   'Premium Motors',
#   'Rua João Pedro de Souza,73 - Jardim Monte Líbano - Campo Grande / MS'],
#  ['Fiesta Hatch SE 1.0 4p.',
#   '13/14',
#   'Preta',
#   'Flex',
#   'Não disponível',
#   'R$\xa029.990,00',
#   'https://www.shopcar.com.br/veiculos/ford/fiesta-hatch-se-1-0-4p/13-14/1180147',
#   'Gauchinho Veículos',
#   'Av. Hayel Bon Faker, 1247 - Jardim Água Boa - Dourados / MS'],
#  ['Logan Expression 1.6',
#   '12/12',
#   'Prata',
#   'Flex',
#   'Não disponível',
#   'R$\xa029.990,00',
#   'https://www.shopcar.com.br/veiculos/renault/logan-expression-1-6/12-12/1192288',
#   'Meu Carro Novo',
#   'Av. Weimar Gonçalves Torres, 4150 - Jardim Caramuru - Dourados / MS'],
#  ['Uno Vivace 1.0 4p.',
#   '11/12',
#   'Cinza',
#   'Flex',
#   'Não disponível',
#   'R$\xa029.990,00',
#   'https://www.shopcar.com.br/veiculos/fiat/uno-vivace-1-0-4p/11-12/1199204',
#   'Interlagos Automóveis',
#   'R. Maranhão,  335 - Vila Rica - Campo Grande / MS'],
#  ['Blazer Std. 2.4',
#   '02/02',
#   'Prata',
#   'Gasolina',
#   'Não disponível',
#   'R$\xa030.000,00',
#   'https://www.shopcar.com.br/veiculos/gm-chevrolet/blazer-std-2-4/02-02/1201133',
#   'Lucas Gabriel Ramos',
#   'Campo Grande - MS'],
#  ['Corsa Sedan Classic LS 1.0',
#   '13/14',
#   'Prata',
#   'Flex',
#   'Não disponível',
#   'R$\xa030.000,00',
#   'https://www.shopcar.com.br/veiculos/gm-chevrolet/corsa-sedan-classic-ls-1-0/13-14/1197986',
#   'Auto Car & Pub',
#   'Av. Rita Vieira de Andrade, 1316 - Rita Vieira - Campo Grande / MS'],
#  ['Towner 1.0 Baú',
#   '11/12',
#   'Branca',
#   'Gasolina',
#   'Não disponível',
#   'R$\xa030.000,00',
#   'https://www.shopcar.com.br/veiculos/hafei/towner-1-0-ba/11-12/1169483',
#   'Meu Carro Novo',
#   'Av. Weimar Gonçalves Torres, 4150 - Jardim Caramuru - Dourados / MS'],
#  ['Celta LT 1.0 4p.',
#   '14/15',
#   'Branca',
#   'Flex',
#   'Não disponível',
#   'R$\xa031.900,00',
#   'https://www.shopcar.com.br/veiculos/gm-chevrolet/celta-lt-1-0-4p/14-15/1190564',
#   'Premium Auto Car',
#   'Av. Ricardo Brandão, 778 - Itanhangá Park - Campo Grande / MS'],
#  ['Gol Trend 1.0 4p.',
#   '12/13',
#   'Branca',
#   'Flex',
#   'Não disponível',
#   'R$\xa031.900,00',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/gol-trend-1-0-4p/12-13/1182177',
#   'João Daral Veículos',
#   'R. Dom Pedro I, 405 - Vila Industrial - Dourados / MS'],
#  ['March SR 1.6 16v',
#   '11/12',
#   'Cinza',
#   'Flex',
#   'Não disponível',
#   'R$\xa031.900,00',
#   'https://www.shopcar.com.br/veiculos/nissan/march-sr-1-6-16v/11-12/1204227',
#   'Suelen Regina Wengrat de Lima',
#   'Campo Grande - MS'],
#  ['Palio Attractive 1.4 4p.',
#   '10/11',
#   'Branca',
#   'Flex',
#   'Não disponível',
#   'DETALHES',
#   'https://www.shopcar.com.br/veiculos/fiat/palio-attractive-1-4-4p/10-11/1170591',
#   'Ustulin Multimarcas',
#   'Av. Pres. Ernesto Geisel, 5633 - Cabreúva - Campo Grande / MS'],
#  ['Palio 1.0 Fire 4p.',
#   '14/14',
#   'Branca',
#   'Flex',
#   'Não disponível',
#   'R$\xa032.000,00',
#   'https://www.shopcar.com.br/veiculos/fiat/palio-1-0-fire-4p/14-14/1199191',
#   'Auto Car & Pub',
#   'Av. Rita Vieira de Andrade, 1316 - Rita Vieira - Campo Grande / MS'],
#  ['Uno Way 1.0 4p.',
#   '11/12',
#   'Cinza',
#   'Flex',
#   'Não disponível',
#   'R$\xa032.500,00',
#   'https://www.shopcar.com.br/veiculos/fiat/uno-way-1-0-4p/11-12/1190740',
#   'Automóbile Multimarcas',
#   'Av. Ricardo Brandão, 646 - Itanhangá Park - Campo Grande / MS'],
#  ['Uno Mille Celebration Way 1.0 Fire 4p.',
#   '13/13',
#   'Prata',
#   'Flex',
#   'Não disponível',
#   'DETALHES',
#   'https://www.shopcar.com.br/veiculos/fiat/uno-mille-celebration-way-1-0-fire-4p/13-13/1198478',
#   'MGR Veículos',
#   'Av. Afonso Pena, 3865 - Centro - Campo Grande / MS'],
#  ['Fiesta Sedan SE 1.6',
#   '13/14',
#   'Prata',
#   'Flex',
#   'Não disponível',
#   'R$\xa032.990,00',
#   'https://www.shopcar.com.br/veiculos/ford/fiesta-sedan-se-1-6/13-14/1195442',
#   'CR Motors',
#   'Rua Joaquim Murtinho, 1872 - Itanhangá Park - Campo Grande / MS'],
#  ['Gol 1.0 4p.',
#   '12/13',
#   'Preta',
#   'Flex',
#   'Não disponível',
#   'DETALHES',
#   'https://www.shopcar.com.br/veiculos/vw-volkswagen/gol-1-0-4p/12-13/1148477',
#   'Nill Car',
#   'Rua 26 de Agosto, 1580 - Amambaí - Campo Grande / MS'],
#  ['Sandero Expression 1.0 16v',
#   '14/14',
#   'Prata',
#   'Flex',
#   'Não disponível',
#   'R$\xa033.800,00',
#   'https://www.shopcar.com.br/veiculos/renault/sandero-expression-1-0-16v/14-14/1197084',
#   'Marreco Veículos',
#   'Rua Amazonas, 1237 - Centro - Campo Grande / MS']]
