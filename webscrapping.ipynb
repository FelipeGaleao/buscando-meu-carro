# %%
from bs4 import BeautifulSoup
import requests
import csv
import pandas

# %%
carro_dados = []
for pagina in range(562):
    print(f"Iniciando scrapping ...... {pagina}")
    url = f"https://www.shopcar.com.br/busca.php?tipo=1&marca=&string=&ordenar=valor_asc&pagina={pagina}"
    res = requests.get(url)
    soup = BeautifulSoup(res.text)
    index = 0
    for carro in soup.find_all(class_='destaque-lista'):
        carro_modelo = carro('li')[1]('div')[0].get_text()
        anoModelo_anoFabricacao = carro('li')[1]('div')[2].get_text()
        corCarro = carro('li')[1]('div')[3].get_text()
        combustivelCarro = carro('li')[1]('div')[4].get_text()
        preco = carro(class_='preco')[0].get_text()
        try:
            kmCarro = carro(class_='caract-km')[0].get_text()
        except:
            kmCarro = 'Não disponível'
        link_veiculo = carro('a')[1].get('href')
        url = link_veiculo
        res = requests.get(url)
        soup = BeautifulSoup(res.text)
        vendedor = soup.find_all(class_='dados1')[0].find_all(class_='nome')[0].get_text()
        cidade = soup.find_all(class_='dados1')[0].find_all(class_='endereco')[0].get_text()
        index += 1
        carro_dados.append([carro_modelo, anoModelo_anoFabricacao, corCarro, combustivelCarro, kmCarro, preco, link_veiculo, vendedor, cidade])
        print(f"Já foram incluídos {index} carros")

    for carro in soup.find_all(class_='itens'):
        carro_modelo = carro('li')[1]('div')[0].get_text()
        anoModelo_anoFabricacao = carro('li')[1]('div')[2].get_text()
        corCarro = carro('li')[1]('div')[3].get_text()
        combustivelCarro = carro('li')[1]('div')[4].get_text()
        preco = carro(class_='preco')[0].get_text()
        try:
            kmCarro = carro(class_='caract-km')[0].get_text()
        except:
            kmCarro = 'Não disponível'
        link_veiculo = carro('a')[1].get('href')
        url = link_veiculo
        res = requests.get(url)
        soup = BeautifulSoup(res.text)
        vendedor = soup.find_all(class_='dados1')[0].find_all(class_='nome')[0].get_text()
        cidade = soup.find_all(class_='dados1')[0].find_all(class_='endereco')[0].get_text()
        index += 1
        carro_dados.append([carro_modelo, anoModelo_anoFabricacao, corCarro, combustivelCarro, kmCarro, preco, link_veiculo, vendedor, cidade])
        
        print(f"Já foram incluídos {index} carros")
# Out:
# Iniciando scrapping ...... 0
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 1
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 2
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 3
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 4
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 5
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 6
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 7
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 8
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 9
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 10
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 11
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 12
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 13
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 14
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 15
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 16
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 17
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 18
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 19
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 20
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 21
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 22
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 23
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 24
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 25
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 26
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 27
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 28
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 29
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 30
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 31
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 32
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 33
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 34
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 35
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 36
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 37
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 38
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 39
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 40
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 41
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 42
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 43
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 44
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 45
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 46
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 47
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 48
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 49
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 50
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 51
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 52
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Iniciando scrapping ...... 53
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 54
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 55
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 56
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 57
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 58
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 59
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 60
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 61
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 62
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 63
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 64
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 65
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 66
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 67
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 68
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 69
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 70
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 71
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 72
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 73
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 74
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 75
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 76
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 77
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 78
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 79
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# ...
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 536
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 537
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 538
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 539
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 540
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 541
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 542
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 543
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 544
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 545
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 546
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 547
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 548
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 549
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 550
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 551
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 552
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 553
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 554
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 555
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 556
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 557
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 558
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 559
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 560
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros
# Iniciando scrapping ...... 561
# Já foram incluídos 1 carros
# Já foram incluídos 2 carros
# Já foram incluídos 3 carros
# Já foram incluídos 4 carros
# Já foram incluídos 5 carros
# Já foram incluídos 6 carros
# Já foram incluídos 7 carros
# Já foram incluídos 8 carros
# Já foram incluídos 9 carros
# Já foram incluídos 10 carros
# Já foram incluídos 11 carros
# Já foram incluídos 12 carros
# Já foram incluídos 13 carros
# Já foram incluídos 14 carros
# Já foram incluídos 15 carros
# Já foram incluídos 16 carros
# Já foram incluídos 17 carros
# Já foram incluídos 18 carros
# Já foram incluídos 19 carros
# Já foram incluídos 20 carros

# %%
carros_df = pandas.DataFrame(carro_dados)
carros_df.columns = ['Modelo', 'Ano', 'Cor',' Combustível','KM', 'Preco', 'Link', 'Vendedor', 'Cidade']
carros_df.to_csv('output/scrapping_nuncios_shopcar.csv')
